# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

from matplotlib import rcParams

# %%
# %matplotlib inline
rcParams['figure.figsize'] = 5,6

# %%
file = '/Users/labattula/Documents/Lakshman/Future-ML/MyDS/matches.csv'
file
# Out:
# '/Users/labattula/Documents/Lakshman/Future-ML/MyDS/matches.csv'

# %%
DF_matches = pd.read_csv(file)
DF_matches.head()
# Out:
#    id  season        city        date                  team1  \
# 0   1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1   2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2   3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3   4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4   5    2008     Kolkata  2008-04-20        Deccan Chargers
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1              Kings XI Punjab          Chennai Super Kings           bat
# 2             Delhi Daredevils             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4        Kolkata Knight Riders              Deccan Chargers           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0        Kolkata Knight Riders          140
# ...

# %%
seasons = DF_matches['season']
seasons
# Out:
# 0      2008
# 1      2008
# 2      2008
# 3      2008
# 4      2008
# 5      2008
# 6      2008
# 7      2008
# 8      2008
# 9      2008
# 10     2008
# 11     2008
# 12     2008
# 13     2008
# 14     2008
# 15     2008
# 16     2008
# 17     2008
# 18     2008
# 19     2008
# 20     2008
# 21     2008
# 22     2008
# 23     2008
# 24     2008
# 25     2008
# 26     2008
# 27     2008
# 28     2008
# 29     2008
#        ...
# 547    2016
# 548    2016
# 549    2016
# 550    2016
# 551    2016
# 552    2016
# 553    2016
# 554    2016
# 555    2016
# 556    2016
# 557    2016
# 558    2016
# 559    2016
# 560    2016
# 561    2016
# 562    2016
# 563    2016
# 564    2016
# 565    2016
# 566    2016
# 567    2016
# 568    2016
# 569    2016
# 570    2016
# 571    2016
# 572    2016
# 573    2016
# 574    2016
# 575    2016
# 576    2016
# Name: season, dtype: int64

# %%
team_name = 'Royal Challengers Bangalore'
DF_RCB = DF_matches.loc[(DF_matches['team1'] == team_name) | (DF_matches['team2'] == team_name)]
DF_RCB
# Out:
#       id  season            city        date                        team1  \
# 0      1    2008       Bangalore  2008-04-18        Kolkata Knight Riders
# 3      4    2008          Mumbai  2008-04-20               Mumbai Indians
# 10    11    2008       Bangalore  2008-04-26  Royal Challengers Bangalore
# 14    15    2008       Bangalore  2008-04-28          Chennai Super Kings
# 16    17    2008           Delhi  2008-04-30             Delhi Daredevils
# 20    21    2008       Hyderabad  2008-05-25              Deccan Chargers
# 24    25    2008       Bangalore  2008-05-05  Royal Challengers Bangalore
# 28    29    2008         Kolkata  2008-05-08        Kolkata Knight Riders
# 30    31    2008       Bangalore  2008-05-28  Royal Challengers Bangalore
# 34    35    2008      Chandigarh  2008-05-12  Royal Challengers Bangalore
# 41    42    2008          Jaipur  2008-05-17             Rajasthan Royals
# 44    45    2008       Bangalore  2008-05-19  Royal Challengers Bangalore
# ...

# %%
DF_RCB.groupby(['season'])

# %%
RCB_LOSS = DF_RCB.loc[(DF_RCB['winner'] != team_name)]
RCB_LOSS
RCB_WON = DF_RCB.loc[(DF_RCB['winner'] == team_name)]
RCB_WON
# Out:
#       id  season          city        date                        team1  \
# 3      4    2008        Mumbai  2008-04-20               Mumbai Indians
# 20    21    2008     Hyderabad  2008-05-25              Deccan Chargers
# 47    48    2008       Chennai  2008-05-21  Royal Challengers Bangalore
# 51    52    2008     Bangalore  2008-05-03  Royal Challengers Bangalore
# 59    60    2009     Cape Town  2009-04-18  Royal Challengers Bangalore
# 74    75    2009        Durban  2009-04-29        Kolkata Knight Riders
# 79    80    2009        Durban  2009-05-01  Royal Challengers Bangalore
# 83    84    2009  Johannesburg  2009-05-03               Mumbai Indians
# 96    97    2009     Centurion  2009-05-12        Kolkata Knight Riders
# 99   100    2009        Durban  2009-05-14          Chennai Super Kings
# 107  108    2009  Johannesburg  2009-05-19             Delhi Daredevils
# 111  112    2009     Centurion  2009-05-21  Royal Challengers Bangalore
# ...

# %%
RCB_LOSS
# Out:
#       id  season            city        date                        team1  \
# 0      1    2008       Bangalore  2008-04-18        Kolkata Knight Riders
# 10    11    2008       Bangalore  2008-04-26  Royal Challengers Bangalore
# 14    15    2008       Bangalore  2008-04-28          Chennai Super Kings
# 16    17    2008           Delhi  2008-04-30             Delhi Daredevils
# 24    25    2008       Bangalore  2008-05-05  Royal Challengers Bangalore
# 28    29    2008         Kolkata  2008-05-08        Kolkata Knight Riders
# 30    31    2008       Bangalore  2008-05-28  Royal Challengers Bangalore
# 34    35    2008      Chandigarh  2008-05-12  Royal Challengers Bangalore
# 41    42    2008          Jaipur  2008-05-17             Rajasthan Royals
# 44    45    2008       Bangalore  2008-05-19  Royal Challengers Bangalore
# 62    63    2009  Port Elizabeth  2009-04-20          Chennai Super Kings
# 64    65    2009       Cape Town  2009-04-22              Deccan Chargers
# ...

# %%
RCB_LOSS['season'].sum()
# Out:
# 138822

# %%
loss_count = RCB_LOSS.groupby(['season']).size().reset_index().rename(columns={0:'losscount'})

# %%
loss_count = RCB_LOSS.groupby(['season']).size().reset_index().rename(columns={0:'losscount'})
plt.plot(loss_count['season'],loss_count['losscount'])

# %%
loss_count.plot(kind="barh")

# %%
loss_count = RCB_LOSS.groupby(['season']).size().reset_index().rename(columns={0:'losscount'})
loss_count
# Out:
#    season  losscount
# 0    2008         10
# 1    2009          7
# 2    2010          8
# 3    2011          6
# 4    2012          7
# 5    2013          7
# 6    2014          9
# 7    2015          8
# 8    2016          7

# %%
loss_count.plot()

# %%
plt.plot(loss_count['season'],loss_count['losscount'],color='red')

# %%
plt.bar(loss_count['season'],loss_count['losscount'],color='red')
# Out:
# <Container object of 9 artists>

# %%
df = DataFrame(pd.randn(10,4))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-48-c58edf46f209> in <module>()
# ----> 1 df = DataFrame(pd.randn(10,4))
#
# AttributeError: 'module' object has no attribute 'randn'

# %%
df2 = DataFrame(np.random.rand(10,4), columns=['a', 'b', 'c', 'd'])
#DF_obj = DataFrame(np.random.rand(36).reshape(6,6))
df2
# Out:
#           a         b         c         d
# 0  0.345976  0.611422  0.058987  0.695954
# 1  0.112525  0.999637  0.632787  0.862323
# 2  0.470451  0.819989  0.272829  0.825338
# 3  0.688452  0.380048  0.543398  0.360786
# 4  0.739884  0.475942  0.048437  0.636814
# 5  0.938975  0.104159  0.892316  0.017879
# 6  0.984711  0.171973  0.129657  0.436669
# 7  0.416167  0.511872  0.240854  0.143570
# 8  0.790749  0.840574  0.334192  0.341977
# 9  0.888269  0.690588  0.858441  0.798728

# %%
df2.plot(kind='bar',stacked=True)

# %%
won_count = RCB_WON.groupby(['season']).size().reset_index().rename(columns={0:'wincount'})

# %%
won_count
# Out:
#    season  wincount
# 0    2008         4
# 1    2009         9
# 2    2010         8
# 3    2011        10
# 4    2012         8
# 5    2013         9
# 6    2014         5
# 7    2015         8
# 8    2016         9

# %%
rcb_hst = won_count.join(loss_count['losscount'])

# %%
rcb_hst
# Out:
#    season  wincount  losscount
# 0    2008         4         10
# 1    2009         9          7
# 2    2010         8          8
# 3    2011        10          6
# 4    2012         8          7
# 5    2013         9          7
# 6    2014         5          9
# 7    2015         8          8
# 8    2016         9          7

# %%
rcb_hst.plot(kind='bar')

# %%
rcb_hst.bar()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-255a17d60812> in <module>()
# ----> 1 rcb_hst.bar()
#
# /anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'bar'

# %%
rcb_hst.plot(kind='bar',stacked=True)

# %%
rcb_hst
# Out:
#    season  wincount  losscount
# 0    2008         4         10
# 1    2009         9          7
# 2    2010         8          8
# 3    2011        10          6
# 4    2012         8          7
# 5    2013         9          7
# 6    2014         5          9
# 7    2015         8          8
# 8    2016         9          7

# %%
# RCB's lowest run chase - Won
team_name = 'Royal Challengers Bangalore'
DF_RCB = DF_matches.loc[(DF_matches['team1'] == team_name) | (DF_matches['team2'] == team_name)]
DF_RCB
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f2877317e805> in <module>()
#       1 # RCB's lowest run chase - Won
#       2 team_name = 'Royal Challengers Bangalore'
# ----> 3 DF_RCB = DF_matches.loc[(DF_matches['team1'] == team_name) | (DF_matches['team2'] == team_name)]
#       4 DF_RCB
#
# NameError: name 'DF_matches' is not defined

# %%
file
# Out:
# file

# %%
file = '/Users/labattula/Documents/Lakshman/Future-ML/MyDS/matches.csv'
DF_matches = pd.read_csv(file)
DF_matches.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a894863c4f7e> in <module>()
#       1 file = '/Users/labattula/Documents/Lakshman/Future-ML/MyDS/matches.csv'
# ----> 2 DF_matches = pd.read_csv(file)
#       3 DF_matches.head()
#
# NameError: name 'pd' is not defined
